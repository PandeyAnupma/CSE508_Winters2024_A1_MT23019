# %% [markdown]
# <a href="https://colab.research.google.com/github/PandeyAnupma/CSE508_Winters2024_A1_MT23019/blob/main/CSE508_Winters2024_A1_MT23019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Preprocessing

# %%
import os
import shutil
import random
import re
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define folder paths
input_folder = '/content/drive/My Drive/text_files'
initial_folder = '/content/initial_files'
preprocessed_files = '/content/preprocessed_files'


# Create a function for natural sorting
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', s)]

# Function to create directories and copy files
def setup_folders_and_copy():
    # Remove the initial folder if it exists
    try:
        shutil.rmtree(initial_folder)
    except FileNotFoundError:
        pass

    # Copy files to the initial folder
    shutil.copytree(input_folder, initial_folder)

setup_folders_and_copy()
os.chdir(initial_folder)
files = os.listdir(initial_folder)

# Function to preprocess files
def preprocess_files(count=0):
    # Remove the preprocessed folder if it exists
    try:
        shutil.rmtree(preprocessed_files)
    except FileNotFoundError:
        pass

    # Create the preprocessed folder
    os.makedirs(preprocessed_files)

    # Process each file
    for i in range(1, count + 1):
        file = f"file{i}.txt"
        path = os.path.join(preprocessed_files, file)

        # Create empty files
        with open(path, 'w') as file:
            pass

# Main execution
if __name__ == "__main__":
    # Set working directory to the initial folder
    os.chdir(initial_folder)

    # Get the list of files and sort them naturally
    files = os.listdir(initial_folder)
    files = sorted(files, key=natural_sort_key)

    # Display 5 selectedly selected files
    selected_files = random.sample(files, 5)
    selected_files = sorted(selected_files, key=natural_sort_key)
    print(selected_files)

    # Count the number of files
    count = len(files)
    document_id = {}
    for i in range(1,count+1):
        document_id[i] = files[i-1]
    print(document_id)

    # Perform setup and preprocessing

    preprocess_files(count)

tokenized_folder = '/content/tokenized_files'
try:
    shutil.rmtree(tokenized_folder)
except FileNotFoundError:
    pass
os.makedirs("/content/tokenized_files")
for i in range(1, count+1):
    file = f"file{i}.txt"
    path = os.path.join(tokenized_folder, file)
    with open(path, 'w') as file:
        pass
# Out:
# Mounted at /content/drive
# ['file397.txt', 'file412.txt', 'file726.txt', 'file879.txt', 'file908.txt']
# ...

# %%
import os
import pandas as pd

def read_file_content(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def write_file_content(file_path, content):
    with open(file_path, 'w') as file:
        file.write(content)

def preprocess_files(initial_folder, preprocessed_files, files, selected_files):
    print("Before preprocessing:\n")

    for filename in files:
        initial_path = os.path.join(initial_folder, filename)
        with open(initial_path, 'r') as initial_file:
            content = initial_file.read()

            if filename in selected_files:
                print(f"{filename} :")
                print(content, end="\n\n")

            content = content.lower()

        preprocessed_path = os.path.join(preprocessed_files, filename)
        write_file_content(preprocessed_path, content)

    print("----------------------------------------------------------------")
    print("After preprocessing:\n")

    for filename in selected_files:
        preprocessed_path = os.path.join(preprocessed_files, filename)
        content = read_file_content(preprocessed_path)

        print(f"{filename} :")
        print(content, end="\n\n")

if __name__ == "__main__":
    initial_folder = '/content/initial_files'
    preprocessed_files = '/content/preprocessed_files'

    # Assuming you have 'files' and 'selected_files' defined previously
    preprocess_files(initial_folder, preprocessed_files, files, selected_files)
# Out:
# Before preprocessing:
#
# file397.txt :
# Absolutely love it. Does exactly what I need it to do with utmost confidence. I can even shove 6 guitars, acoustic or electric IN CASES with this rack. Is it expensive? Yes, but is it worth it? Many times over.
#
# file412.txt :
# I recently got a used, but excellent, Epiphone Junior.  I've been playing for over fifty years and owned many -- many quite fine, costly, guitars. But as others have discovered, these older, P90-equipped Epis belie their cost. They play and sound GREAT.  With one exception: They come with pretty poor tuners.
#
# A guitar forum friend had suggested these Grovers and I'm glad I listened. They are quality pieces that, apart from the mounting screw placement, are complete "drop ins."
#
# Fairly priced here on Amazon.  I could not be more pleased!
#
# file726.txt :
# ...

# %%
import os
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

def read_file_content(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def write_content_to_file(file_path, content):
    with open(file_path, 'w') as file:
        file.write(content)

def tokenize_and_preprocess(files, preprocessed_files, tokenized_folder, selected_files):
    print("Before preprocessing:\n")

    for filename in files:
        preprocessed_path = os.path.join(preprocessed_files, filename)
        tokenized_path = os.path.join(tokenized_folder, filename)

        content = read_file_content(preprocessed_path)

        if filename in selected_files:
            print(f"{filename} :")
            print(content, end="\n\n")

        tokens = word_tokenize(content)

        write_content_to_file(preprocessed_path, str(tokens))
        write_content_to_file(tokenized_path, str(tokens))

    print("----------------------------------------------------------------")
    print("After preprocessing:\n")

    for filename in selected_files:
        preprocessed_path = os.path.join(preprocessed_files, filename)

        with open(preprocessed_path, 'r') as file:
            content = file.read()
            print(f"{filename} :")
            print(content, end="\n\n")

if __name__ == "__main__":
    initial_folder = '/content/initial_files'
    preprocessed_files = '/content/preprocessed_files'
    # Assuming you have 'files', 'preprocessed_files', 'tokenized_folder', and 'selected_files' defined previously
    tokenize_and_preprocess(files, preprocessed_files, tokenized_folder, selected_files)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Before preprocessing:
#
# file397.txt :
# absolutely love it. does exactly what i need it to do with utmost confidence. i can even shove 6 guitars, acoustic or electric in cases with this rack. is it expensive? yes, but is it worth it? many times over.
#
# file412.txt :
# i recently got a used, but excellent, epiphone junior.  i've been playing for over fifty years and owned many -- many quite fine, costly, guitars. but as others have discovered, these older, p90-equipped epis belie their cost. they play and sound great.  with one exception: they come with pretty poor tuners.
#
# a guitar forum friend had suggested these grovers and i'm glad i listened. they are quality pieces that, apart from the mounting screw placement, are complete "drop ins."
#
# fairly priced here on amazon.  i could not be more pleased!
#
# file726.txt :
# ...

# %%
 from nltk.corpus import stopwords
import ast

def read_file_content(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def write_file_content(file_path, content):
    with open(file_path, 'w') as file:
        file.write(content)

def remove_stopwords(files, selected_files, preprocessed_files):
    nltk.download('stopwords')
    stop_words = set(stopwords.words('english'))

    print("Before preprocessing:\n")

    for filename in files:
        path = os.path.join(preprocessed_files, filename)
        content = read_file_content(path)

        if filename in selected_files:
            print(f"{filename} :")
            print(content, end="\n\n")

        tokens = ast.literal_eval(content)
        stripped = [token for token in tokens if token.lower() not in stop_words]

        write_file_content(path, str(stripped))

    print("----------------------------------------------------------------")
    print("After preprocessing:\n")

    for filename in selected_files:
        path = os.path.join(preprocessed_files, filename)
        content = read_file_content(path)

        print(f"{filename} :")
        print(content, end="\n\n")

if __name__ == "__main__":
    initial_folder = '/content/initial_files'
    preprocessed_files = '/content/preprocessed_files'

    # Assuming you have 'files' and 'selected_files' defined previously
    remove_stopwords(files, selected_files, preprocessed_files)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Before preprocessing:
#
# file397.txt :
# ['absolutely', 'love', 'it', '.', 'does', 'exactly', 'what', 'i', 'need', 'it', 'to', 'do', 'with', 'utmost', 'confidence', '.', 'i', 'can', 'even', 'shove', '6', 'guitars', ',', 'acoustic', 'or', 'electric', 'in', 'cases', 'with', 'this', 'rack', '.', 'is', 'it', 'expensive', '?', 'yes', ',', 'but', 'is', 'it', 'worth', 'it', '?', 'many', 'times', 'over', '.']
#
# file412.txt :
# ...

# %%
import string
punctuations = set(string.punctuation)

def read_file_content(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def write_file_content(file_path, content):
    with open(file_path, 'w') as file:
        file.write(content)

def remove_punctuations(files, selected_files, preprocessed_files):
    print("Before preprocessing:\n")

    for filename in files:
        path = os.path.join(preprocessed_files, filename)
        content = read_file_content(path)

        if filename in selected_files:
            print(f"{filename} :")
            print(content, end="\n\n")

        tokens = ast.literal_eval(content)
        stripped = [token for token in tokens if token.lower() not in punctuations]

        write_file_content(path, str(stripped))

    print("----------------------------------------------------------------")
    print("After preprocessing:\n")

    for filename in selected_files:
        path = os.path.join(preprocessed_files, filename)
        content = read_file_content(path)

        print(f"{filename} :")
        print(content, end="\n\n")

if __name__ == "__main__":
    initial_folder = '/content/initial_files'
    preprocessed_files = '/content/preprocessed_files'

    # Assuming you have 'files' and 'selected_files' defined previously
    remove_punctuations(files, selected_files, preprocessed_files)
# Out:
# Before preprocessing:
#
# file397.txt :
# ['absolutely', 'love', '.', 'exactly', 'need', 'utmost', 'confidence', '.', 'even', 'shove', '6', 'guitars', ',', 'acoustic', 'electric', 'cases', 'rack', '.', 'expensive', '?', 'yes', ',', 'worth', '?', 'many', 'times', '.']
#
# file412.txt :
# ['recently', 'got', 'used', ',', 'excellent', ',', 'epiphone', 'junior', '.', "'ve", 'playing', 'fifty', 'years', 'owned', 'many', '--', 'many', 'quite', 'fine', ',', 'costly', ',', 'guitars', '.', 'others', 'discovered', ',', 'older', ',', 'p90-equipped', 'epis', 'belie', 'cost', '.', 'play', 'sound', 'great', '.', 'one', 'exception', ':', 'come', 'pretty', 'poor', 'tuners', '.', 'guitar', 'forum', 'friend', 'suggested', 'grovers', "'m", 'glad', 'listened', '.', 'quality', 'pieces', ',', 'apart', 'mounting', 'screw', 'placement', ',', 'complete', '``', 'drop', 'ins', '.', "''", 'fairly', 'priced', 'amazon', '.', 'could', 'pleased', '!']
#
# file726.txt :
# ...

# %%
def read_file_content(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def write_file_content(file_path, content):
    with open(file_path, 'w') as file:
        file.write(content)

def preprocess_and_strip_whitespace(files, selected_files, preprocessed_files):
    print("Before preprocessing:\n")

    for filename in files:
        path = os.path.join(preprocessed_files, filename)
        content = read_file_content(path)

        if filename in selected_files:
            print(f"{filename} :")
            print(content, end="\n\n")

        tokens = ast.literal_eval(content)
        stripped = [token for token in tokens if token.lower().strip()]

        write_file_content(path, str(stripped))

    print("----------------------------------------------------------------")
    print("After preprocessing:\n")

    for filename in selected_files:
        path = os.path.join(preprocessed_files, filename)
        content = read_file_content(path)

        print(f"{filename} :")
        print(content, end="\n\n")

if __name__ == "__main__":
    initial_folder = '/content/initial_files'
    preprocessed_files = '/content/preprocessed_files'

    # Assuming you have 'files' and 'selected_files' defined previously
    preprocess_and_strip_whitespace(files, selected_files, preprocessed_files)
# Out:
# Before preprocessing:
#
# file397.txt :
# ['absolutely', 'love', 'exactly', 'need', 'utmost', 'confidence', 'even', 'shove', '6', 'guitars', 'acoustic', 'electric', 'cases', 'rack', 'expensive', 'yes', 'worth', 'many', 'times']
#
# file412.txt :
# ['recently', 'got', 'used', 'excellent', 'epiphone', 'junior', "'ve", 'playing', 'fifty', 'years', 'owned', 'many', '--', 'many', 'quite', 'fine', 'costly', 'guitars', 'others', 'discovered', 'older', 'p90-equipped', 'epis', 'belie', 'cost', 'play', 'sound', 'great', 'one', 'exception', 'come', 'pretty', 'poor', 'tuners', 'guitar', 'forum', 'friend', 'suggested', 'grovers', "'m", 'glad', 'listened', 'quality', 'pieces', 'apart', 'mounting', 'screw', 'placement', 'complete', '``', 'drop', 'ins', "''", 'fairly', 'priced', 'amazon', 'could', 'pleased']
#
# file726.txt :
# ['excellent', '2', 'tier', 'keyboard', 'stand', 'exactly', 'needed', 'fact', 'came', 'better', 'expected', 'hard', 'believe', "'s", '27', 'see', 'photos']
#
# file879.txt :
# ...

# %% [markdown]
# **Unigram Inverted Index**

# %%
# !pip install ordered_set
import os
import ast
from ordered_set import OrderedSet

def read_file_content(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def build_index(files, preprocessed_files):
    index = {}

    # Mapping document IDs to filenames
    document_id = {i+1: filename for i, filename in enumerate(files)}

    for doc_id, filename in document_id.items():
        path = os.path.join(preprocessed_files, filename)
        content = read_file_content(path)
        tokens = ast.literal_eval(content)

        for token in tokens:
            if token not in index:
                index[token] = [1, OrderedSet([doc_id])]
            else:
                if doc_id in index[token][1]:
                    pass
                else:
                    index[token][0] += 1
                    index[token][1].add(doc_id)

    return index

if __name__ == "__main__":
    initial_folder = '/content/initial_files'
    preprocessed_files = '/content/preprocessed_files'

    # Assuming you have 'files' defined previously
    unigram_index = build_index(files, preprocessed_files)
    print(unigram_index)
# Out:
# ...
# {'loving': [4, OrderedSet([1, 254, 391, 723])], 'vintage': [18, OrderedSet([1, 51, 150, 197, 278, 422, 439, 494, 597, 638, 674, 725, 737, 827, 847, 895, 907, 936])], 'springs': [5, OrderedSet([1, 272, 469, 806, 937])], 'strat': [36, OrderedSet([1, 25, 90, 149, 163, 197, 241, 245, 253, 345, 353, 380, 396, 400, 422, 440, 455, 457, 469, 519, 529, 559, 565, 579, 611, 626, 650, 652, 691, 725, 801, 838, 853, 940, 978, 993])], 'good': [204, OrderedSet([1, 2, 4, 8, 9, 13, 16, 18, 19, 28, 29, 30, 37, 40, 43, 44, 46, 58, 65, 72, 77, 78, 85, 90, 96, 103, 106, 110, 111, 115, 118, 137, 141, 143, 154, 155, 157, 159, 160, 162, 163, 164, 166, 172, 174, 175, 176, 179, 189, 204, 207, 210, 217, 220, 234, 235, 240, 245, 252, 254, 265, 274, 277, 282, 288, 292, 293, 299, 304, 305, 311, 316, 321, 325, 332, 338, 342, 347, 354, 355, 358, 362, 367, 378, 390, 393, 396, 400, 404, 407, 413, 422, 455, 471, 493, 497, 499, 501, 503, 513, 522, 525, 526, 532, 536, 539, 541, 544, 549, 551, 571, 575, 584, 585, 586, 595
# ...

# %%
import pickle

with open('/content/drive/My Drive/unigram_index.pkl', 'wb') as file:
    pickle.dump(unigram_index, file)

# %%
import pickle
with open('/content/drive/My Drive/unigram_index.pkl', 'rb') as file:
    unigram_index = pickle.load(file)

print(unigram_index)
# Out:
# {'loving': [4, OrderedSet([1, 254, 391, 723])], 'vintage': [18, OrderedSet([1, 51, 150, 197, 278, 422, 439, 494, 597, 638, 674, 725, 737, 827, 847, 895, 907, 936])], 'springs': [5, OrderedSet([1, 272, 469, 806, 937])], 'strat': [36, OrderedSet([1, 25, 90, 149, 163, 197, 241, 245, 253, 345, 353, 380, 396, 400, 422, 440, 455, 457, 469, 519, 529, 559, 565, 579, 611, 626, 650, 652, 691, 725, 801, 838, 853, 940, 978, 993])], 'good': [204, OrderedSet([1, 2, 4, 8, 9, 13, 16, 18, 19, 28, 29, 30, 37, 40, 43, 44, 46, 58, 65, 72, 77, 78, 85, 90, 96, 103, 106, 110, 111, 115, 118, 137, 141, 143, 154, 155, 157, 159, 160, 162, 163, 164, 166, 172, 174, 175, 176, 179, 189, 204, 207, 210, 217, 220, 234, 235, 240, 245, 252, 254, 265, 274, 277, 282, 288, 292, 293, 299, 304, 305, 311, 316, 321, 325, 332, 338, 342, 347, 354, 355, 358, 362, 367, 378, 390, 393, 396, 400, 404, 407, 413, 422, 455, 471, 493, 497, 499, 501, 503, 513, 522, 525, 526, 532, 536, 539, 541, 544, 549, 551, 571, 575, 584, 585, 586, 595
# ...

# %%
import nltk
from nltk.corpus import stopwords
import string

# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')

def query_preprocess(text):
    # Lowercase the text
    text = text.lower()

    # Tokenization
    tokens = nltk.word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [i for i in tokens if i not in stop_words]

    # Remove punctuations
    tokens = [i for i in tokens if i not in string.punctuation]

    # Remove blank space tokens
    tokens = [i for i in tokens if i.strip()]

    return tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Query Processing**

# %%
def operation_and(list1, list2):
    i = j = 0
    output = []
    if list1==[] or list2==[]:
        return output
    while i<len(list1) and j<len(list2):
        if list1[i] == list2[j]:
            output.append(list1[i])
            i+=1
            j+=1
        elif list1[i] <list2[j]:
            i+=1
        else:
            j+=1
    return output

def operation_and_not(list1, list2):
    i = j = 0
    output = []
    if list1==[]:
        return output
    elif list2==[]:
        return list1
    while i<len(list1) and j<len(list2):
        if list1[i] == list2[j]:
            i+=1
            j+=1
        elif list1[i] < list2[j]:
            output.append(list1[i])
            i+=1
        else:
            j+=1
    return output

def operation_or(list1, list2):
    i = j = 0
    output = []
    if list1==[]:
        return list2
    elif list2==[]:
        return list1
    while i<len(list1) and j<len(list2):
        if list1[i] == list2[j]:
            output.append(list1[i])
            i+=1
            j+=1
        elif list1[i] <list2[j]:
            output.append(list1[i])
            i+=1
        else:
            output.append(list2[j])
            j+=1
    while i<len(list1) and j>=len(list2):
        output.append(list1[i])
        i+=1
    while i>=len(list1) and j<len(list2):
        output.append(list2[j])
        j+=1
    return output

def operation_or_not(list1,list2):
    output = operation_not(list2)
    return operation_or(list1,output)

def operation_not(list1):
    universal_set = list(document_id.keys())
    output=[]
    i=k=0
    while i<len(list1) and k<len(universal_set):
        if universal_set[k] == list1[i]:
            i+=1
            k+=1
        elif universal_set[k] < list1[i]:
            output.append(universal_set[k])
            k+=1
    while k<len(universal_set):
        output.append(universal_set[k])
        k+=1
    return output

print("write your query in the following manner:\nline 1: number of queries to execute\nline 2: input sequence for query 1, seperated by comma\nline 3: operations, seperated by comma\n")
n = int(input())

# Query processing
for k in range(0,n):

    flag = False
    while flag==False:
        # print("write your query in the following manner:\nline 2: input sequence for query 1, seperated by space\nline 3: operations, seperated by comma\n")
        seq = input()
        op = input()
        terms = query_preprocess(seq)
        # print(terms)
        op = op.lower()
        op = op.split(sep=",")
        for i in op:
            if len(op) > len(terms):
                flag = False
                print("Invalid input! Operator count do not sync with terms count.\n")
                break
            if i not in ("and", "or", "not", "and not", "or not"):
                flag = False
                print("Invalid input! Use a valid operator.\n")
                break
            flag = True

    print("\n\nQuery: ",end="")
    i=j=0
    while i<len(op) and j<len(terms):
        if op[0]=="not":
            print(op[i].upper(),terms[j],end=" ")
            i+=1
            j+=1
        else:
            print(terms[j],op[i].upper(),end=" ")
            i+=1
            j+=1
    if j<len(terms):
        print(terms[j])

    term1 = terms[0]
    try:
        output = unigram_index[term1][1]
    except:
        output=[]
    for i in range(1,len(op)+1):
        try:
            term2 = terms[i]
            list2 = unigram_index[term2][1]
        except:
            list2=[]
        operation = op[i-1]
        list1 = output
        # print(list1, list2)
        if operation == "and":
            output = operation_and(list1, list2)
        elif operation == "and not":
            output = operation_and_not(list1, list2)
        elif operation == "or":
            output = operation_or(list1, list2)
        elif operation == "or not":
            output = operation_or_not(list1, list2)
        else:
            output = operation_not(list1)
        # print(output)

    print("\nNo. of documents retreived: ",len(output))
    print("Documents retreived: ", end="")
    for x in output:
        print(document_id[x],end=", ")
    print("\n\n")
# Out:
# write your query in the following manner:
# line 1: number of queries to execute
# line 2: input sequence for query 1, seperated by comma
# line 3: operations, seperated by comma
#
# 1
# highly recommend
# and
#
#
# Query: highly AND recommend
#
# No. of documents retreived:  32
# Documents retreived: file18.txt, file138.txt, file149.txt, file156.txt, file186.txt, file208.txt, file213.txt, file228.txt, file242.txt, file268.txt, file291.txt, file400.txt, file457.txt, file461.txt, file487.txt, file501.txt, file527.txt, file541.txt, file543.txt, file576.txt, file618.txt, file621.txt, file627.txt, file639.txt, file699.txt, file716.txt, file750.txt, file831.txt, file838.txt, file872.txt, file897.txt, file997.txt,

# %% [markdown]
# **Positional Index**

# %%
from ordered_set import OrderedSet

def read_file_content(file_path):
    with open(file_path, 'r') as file:
        return file.read()

def create_positional_index(document_id, preprocessed_files, tokenized_folder):
    positional_index = {}

    for key, value in document_id.items():
        path1 = os.path.join(preprocessed_files, value)
        path2 = os.path.join(tokenized_folder, value)

        p_tokens, t_tokens = get_tokens(path1, path2)

        for token in p_tokens:
            positions = find_positions(token, t_tokens)

            update_index(positional_index, token, key, positions)

    return positional_index

def get_tokens(path1, path2):
    with open(path1, 'r') as p_file, open(path2, 'r') as t_file:
        p_content = p_file.read()
        t_content = t_file.read()

        try:
            p_tokens = ast.literal_eval(p_content)
            t_tokens = ast.literal_eval(t_content)
            return p_tokens, t_tokens
        except Exception as e:
            print("Failed to parse tokens:", e)
            return [], []

def find_positions(token, tokens):
    return [pos for pos, t_token in enumerate(tokens) if t_token == token]

def update_index(positional_index, token, key, positions):
    if token not in positional_index:
        positional_index[token] = [1, {key: positions}]
    else:
        if key not in positional_index[token][1]:
            positional_index[token][0] += 1
            positional_index[token][1][key] = positions

if __name__ == "__main__":
    positional_index = create_positional_index(document_id, preprocessed_files, tokenized_folder)
    print(positional_index)
    print(positional_index.keys())
# Out:
# {'loving': [4, {1: [0], 254: [68], 391: [7], 723: [8]}], 'vintage': [18, {1: [2, 6], 51: [63], 150: [26], 197: [10, 73], 278: [9], 422: [14], 439: [8, 62], 494: [17], 597: [65], 638: [138], 674: [63], 725: [37], 737: [15], 827: [56], 847: [27, 114], 895: [38], 907: [1], 936: [44]}], 'springs': [5, {1: [3, 31], 272: [2, 21], 469: [67], 806: [12], 937: [53, 113]}], 'strat': [36, {1: [7], 25: [5, 11], 90: [8], 149: [8], 163: [121, 155], 197: [25], 241: [7], 245: [10], 253: [49], 345: [13], 353: [115], 380: [16, 35, 42, 102], 396: [10, 96, 127], 400: [137], 422: [18], 440: [12, 71], 455: [56], 457: [5], 469: [17], 519: [12, 103], 529: [65], 559: [41, 46], 565: [12], 579: [24], 611: [139], 626: [20, 30], 650: [14, 29], 652: [58], 691: [4, 102], 725: [45], 801: [11], 838: [14], 853: [7, 17], 940: [6], 978: [19], 993: [65]}], 'good': [204, {1: [12], 2: [43], 4: [3], 8: [23], 9: [20], 13: [57, 66], 16: [8], 18: [82], 19: [7], 28: [193], 29: [154], 30: [59], 37: [42], 40: [47], 43: [38, 134],
# ...

# %%
import pickle

with open('/content/drive/My Drive/positional_ind.pkl', 'wb') as file:
    pickle.dump(positional_index, file)

# %%
with open('/content/drive/My Drive/positional_ind.pkl', 'rb') as file:
    positional_index = pickle.load(file)

print(positional_index)
# Out:
# {'loving': [4, {1: [0], 254: [68], 391: [7], 723: [8]}], 'vintage': [18, {1: [2, 6], 51: [63], 150: [26], 197: [10, 73], 278: [9], 422: [14], 439: [8, 62], 494: [17], 597: [65], 638: [138], 674: [63], 725: [37], 737: [15], 827: [56], 847: [27, 114], 895: [38], 907: [1], 936: [44]}], 'springs': [5, {1: [3, 31], 272: [2, 21], 469: [67], 806: [12], 937: [53, 113]}], 'strat': [36, {1: [7], 25: [5, 11], 90: [8], 149: [8], 163: [121, 155], 197: [25], 241: [7], 245: [10], 253: [49], 345: [13], 353: [115], 380: [16, 35, 42, 102], 396: [10, 96, 127], 400: [137], 422: [18], 440: [12, 71], 455: [56], 457: [5], 469: [17], 519: [12, 103], 529: [65], 559: [41, 46], 565: [12], 579: [24], 611: [139], 626: [20, 30], 650: [14, 29], 652: [58], 691: [4, 102], 725: [45], 801: [11], 838: [14], 853: [7, 17], 940: [6], 978: [19], 993: [65]}], 'good': [204, {1: [12], 2: [43], 4: [3], 8: [23], 9: [20], 13: [57, 66], 16: [8], 18: [82], 19: [7], 28: [193], 29: [154], 30: [59], 37: [42], 40: [47], 43: [38, 134],
# ...

# %% [markdown]
# **Query Preprocessing**

# %%
import nltk
from nltk.corpus import stopwords
import string

# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')

def query_preprocess(text):
    # Lowercase the text
    text = text.lower()

    # Tokenization
    positional_tokens = nltk.word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    positional_tokens = [(x, i) for i, x in enumerate(positional_tokens) if x not in stop_words]

    # Remove punctuations
    positional_tokens = [(x[0], x[1]) for x in positional_tokens if x[0] not in string.punctuation]

    # Remove blank space tokens
    positional_tokens = [(x[0], x[1]) for x in positional_tokens if x[0].strip()]
    positional_tokens = [(x[0], x[1]) for x in positional_tokens if x[0] in positional_index.keys()]
    return positional_tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Phrase Query Processing**

# %%
print("write your query in the following manner:\nline 1: number of queries to execute\nline 2: Phrase query 1\n")
n = int(input())

positional_output_list = []
present = []
positional_terms_list = []

for k in range(0,n):

    seq = input()
    positional_terms = query_preprocess(seq)
    positional_terms_list.append(positional_terms)
    flag = True
    # print(positional_index[positional_terms[0][0]][1])
    positional_output = list(positional_index[positional_terms[0][0]][1].keys())
    for i in positional_terms[1::]:
        j = i[0]
        try:
            list1 = positional_output
            list2 = list(positional_index[j][1].keys())
            positional_output = operation_and(list1,list2)
        except:
            flag = False
            break
    present.append(flag)
    if flag==True:
        positional_output_list.append(positional_output)
    else:
        positional_output_list.append([])


for k in range(0,n):
    final_output = []

    if present[k]:
        num_terms = len(positional_terms_list[k])
        output = []
        for i in positional_output_list[k]:

            flag = True
            term2_pos = positional_terms_list[k][0][1]
            list2 = positional_index[positional_terms_list[k][0][0]][1][i]
            for j in range(1,num_terms):
                count += 1
                positional_diff = positional_terms_list[k][j][1] - positional_terms_list[k][j-1][1]
                list1 = list2
                list2 = positional_index[positional_terms_list[k][j][0]][1][i]

                set1 = set(list1)
                match = False
                for num in list2:
                    if num - positional_diff in set1:
                        match = True
                        break
                        print(num - positional_diff, num, "yes")
                if not match:
                    flag = False
                    break
            if flag==True:
                output.append(i)

        final_output.append(output)
        print("\n\nNumber of documents retrieved for query", k+1, "using positional index:", len(output))
        print("Names of documents retrieved for query", k+1, "using positional index:",end=" ")
        for x in output:
            print(document_id[x],end=", ")
        print("\n\n")

    else:
        print("\nNumber of documents retrieved for query", k+1, "using positional index:", 0)
        print("Names of documents retrieved for query", k+1, "using positional index:","None")
# Out:
# write your query in the following manner:
# line 1: number of queries to execute
# line 2: Phrase query 1
#
# 1
# pick holder
#
#
# Number of documents retrieved for query 1 using positional index: 3
# Names of documents retrieved for query 1 using positional index: file14.txt, file246.txt, file401.txt,
